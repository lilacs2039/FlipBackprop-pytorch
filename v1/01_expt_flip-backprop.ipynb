# %% [markdown]
# # 01_expt_flip-backprop

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
# %pdb on
# Out:
# Automatic pdb calling has been turned ON

# %%
import bnn as bnn
from bnn import *
import wandb

# %% [markdown]
# # Setup

# %%
import fastai
from fastai.tabular.all import *
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from fastai.callback.tensorboard import TensorBoardCallback
from fastai.callback.wandb import WandbCallback

# %% [markdown]
# ## Prepare Dataset

# %%
# Iris load & make DataFrame
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target

train_df, valid_df = train_test_split(df, test_size=0.2, random_state=42)

train_df.reset_index(drop=True, inplace=True)
valid_df.reset_index(drop=True, inplace=True)

cat_names = []
cont_names = iris.feature_names
dep_var = 'target'

# %%
f'num train_df：{len(train_df)}'
# Out:
# 'num train_df：120'

# %% [markdown]
# ## DataLoader

# %%
dls = TabularDataLoaders.from_df(train_df, 
                                 path='.', 
                                 cat_names=cat_names,
                                 cont_names=cont_names, 
                                 y_names=dep_var, 
                                 y_block=CategoryBlock, 
                                 valid_idx=list(valid_df.index),
                                 bs=64,
                                )

# %%
f'num train_ds(dataset) {len(dls.train_ds)}'
# Out:
# 'num train_ds(dataset) 90'

# %% [markdown]
# batch example

# %%
bx_cat, bx, by = dls.one_batch()
bx_cat, bx, by
# Out:
# (tensor([], size=(64, 0), dtype=torch.int64),
#  tensor([[7.0000, 3.2000, 4.7000, 1.4000],
#          [7.3000, 2.9000, 6.3000, 1.8000],
#          [4.9000, 2.4000, 3.3000, 1.0000],
#          [4.3000, 3.0000, 1.1000, 0.1000],
#          [6.7000, 3.0000, 5.0000, 1.7000],
#          [5.4000, 3.4000, 1.7000, 0.2000],
#          [5.1000, 3.5000, 1.4000, 0.3000],
#          [4.8000, 3.4000, 1.9000, 0.2000],
#          [5.5000, 2.6000, 4.4000, 1.2000],
#          [5.3000, 3.7000, 1.5000, 0.2000],
#          [6.0000, 2.2000, 5.0000, 1.5000],
#          [6.0000, 3.0000, 4.8000, 1.8000],
#          [5.7000, 3.0000, 4.2000, 1.2000],
#          [6.0000, 2.2000, 4.0000, 1.0000],
#          [5.1000, 3.8000, 1.6000, 0.2000],
#          [7.2000, 3.2000, 6.0000, 1.8000],
#          [5.0000, 3.4000, 1.5000, 0.2000],
#          [5.0000, 3.5000, 1.6000, 0.6000],
#          [5.6000, 3.0000, 4.1000, 1.3000],
#          [4.9000, 3.6000, 1.4000, 0.1000],
#          [6.4000, 2.9000, 4.3000, 1.3000],
#          [5.7000, 2.6000, 3.5000, 1.0000],
#          [6.1000, 3.0000, 4.6000, 1.4000],
#          [4.9000, 3.1000, 1.5000, 0.2000],
#          [6.2000, 2.9000, 4.3000, 1.3000],
#          [4.9000, 2.5000, 4.5000, 1.7000],
#          [4.6000, 3.1000, 1.5000, 0.2000],
#          [4.9000, 3.0000, 1.4000, 0.2000],
#          [6.5000, 2.8000, 4.6000, 1.5000],
#          [5.0000, 3.2000, 1.2000, 0.2000],
#          [4.6000, 3.2000, 1.4000, 0.2000],
#          [6.1000, 2.8000, 4.0000, 1.3000],
#          [5.0000, 3.0000, 1.6000, 0.2000],
#          [6.0000, 2.7000, 5.1000, 1.6000],
#          [6.6000, 2.9000, 4.6000, 1.3000],
#          [7.2000, 3.0000, 5.8000, 1.6000],
#          [5.1000, 3.4000, 1.5000, 0.2000],
#          [5.9000, 3.2000, 4.8000, 1.8000],
#          [5.5000, 2.3000, 4.0000, 1.3000],
#          [5.6000, 2.7000, 4.2000, 1.3000],
#          [6.3000, 3.4000, 5.6000, 2.4000],
#          [5.1000, 3.7000, 1.5000, 0.4000],
#          [5.5000, 4.2000, 1.4000, 0.2000],
#          [5.7000, 2.5000, 5.0000, 2.0000],
#          [6.3000, 2.5000, 4.9000, 1.5000],
#          [5.8000, 4.0000, 1.2000, 0.2000],
#          [7.7000, 3.0000, 6.1000, 2.3000],
#          [5.9000, 3.0000, 4.2000, 1.5000],
#          [5.8000, 2.6000, 4.0000, 1.2000],
#          [5.8000, 2.7000, 5.1000, 1.9000],
#          [6.3000, 2.9000, 5.6000, 1.8000],
#          [5.8000, 2.8000, 5.1000, 2.4000],
#          [7.7000, 3.8000, 6.7000, 2.2000],
#          [6.9000, 3.2000, 5.7000, 2.3000],
#          [6.2000, 3.4000, 5.4000, 2.3000],
#          [6.7000, 3.3000, 5.7000, 2.1000],
#          [6.3000, 3.3000, 6.0000, 2.5000],
#          [5.1000, 2.5000, 3.0000, 1.1000],
#          [6.1000, 2.6000, 5.6000, 1.4000],
#          [7.4000, 2.8000, 6.1000, 1.9000],
#          [5.5000, 2.4000, 3.8000, 1.1000],
#          [6.2000, 2.8000, 4.8000, 1.8000],
#          [6.3000, 2.7000, 4.9000, 1.8000],
#          [6.4000, 2.7000, 5.3000, 1.9000]]),
#  tensor([[1],
#          [2],
#          [1],
#          [0],
#          [1],
#          [0],
#          [0],
#          [0],
#          [1],
#          [0],
#          [2],
#          [2],
#          [1],
#          [1],
#          [0],
#          [2],
#          [0],
#          [0],
#          [1],
#          [0],
#          [1],
#          [1],
#          [1],
#          [0],
#          [1],
#          [2],
#          [0],
#          [0],
#          [1],
#          [0],
#          [0],
#          [1],
#          [0],
#          [1],
#          [1],
#          [2],
#          [0],
#          [1],
#          [1],
#          [1],
#          [2],
#          [0],
#          [0],
#          [2],
#          [1],
#          [0],
#          [2],
#          [1],
#          [1],
#          [2],
#          [2],
#          [2],
#          [2],
#          [2],
#          [2],
#          [2],
#          [2],
#          [1],
#          [2],
#          [2],
#          [1],
#          [2],
#          [2],
#          [2]], dtype=torch.int8))

# %% [markdown]
# # Model

# %%
class CustomMLP(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(CustomMLP, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.binary_net = self.BinaryNet(hidden_dim, output_dim)

    def forward(self, x_cat, x_cont):
        x = self.fc1(x_cont)
        x = self.relu(x)
        x = self.binary_net(x)
        return x

    class BinaryNet(nn.Module):
        def __init__(self, hidden_features:int=1, out_features:int=1, weights=None, is_standardize=True, pts_sigma=15):
            super().__init__()
            self.binarize = bnn.Binarize(depth_ths=[-1,0,1])
            self.fc2 = bnn.BMA(hidden_features, out_features)
            self.fn = self.BinaryNetFunction.apply

        def forward(self, x):
            x = self.fn(x, self)
            return x 

        class BinaryNetFunction(torch.autograd.Function):
            @staticmethod
            def forward(ctx, x0, model):
                x1 = model.binarize(x0)
                h = model.fc2(x1)
                ctx.save_for_backward(x0,x1)
                ctx.model = model
                return h

            @staticmethod
            def backward(ctx, flip):
                x0,x1 = ctx.saved_tensors
                model = ctx.model
                flip = model.fc2.backward(flip, x1)
                grad = model.binarize.backward(flip, x0)
                return grad, None

input_dim = len(cont_names)
hidden_dim = 64
output_dim = len(iris.target_names)
model = CustomMLP(input_dim, hidden_dim, output_dim)

# %%
model
# Out:
# CustomMLP(
#   (fc1): Linear(in_features=4, out_features=64, bias=True)
#   (relu): ReLU()
#   (binary_net): BinaryNet(
#     (binarize): Binarize()
#     (fc2): BMA(
#       (weights): BinaryTensor(weights=(3, 8), dtype=uint8)
#     )
#   )
# )

# %% [markdown]
# ## Model Graph

# %%
import torchvision.models as models
from torchviz import make_dot

dot = make_dot(model(bx_cat, bx))
dot.format = 'png'
dot_path = 'outputs/graph_image'
dot.render(dot_path)

from IPython.display import Image
display(Image(filename=dot_path+'.png'))

# %% [markdown]
# # Learn

# %%
learn = Learner(dls, model, loss_func=CrossEntropyLossFlat(), metrics=accuracy,
               cbs=[ShowGraphCallback()])

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0063095735386013985)

# %%
learn.dls.bs=64
learn.fit_one_cycle(20, lr_max=1e-2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.147014</td>
#       <td>0.887399</td>
#       <td>0.466667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.022781</td>
#       <td>0.991277</td>
#       <td>0.633333</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.643010</td>
#       <td>0.936148</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.471122</td>
#       <td>0.741914</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.323188</td>
#       <td>0.796766</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.216040</td>
#       <td>0.845946</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.156968</td>
#       <td>0.857243</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.116694</td>
#       <td>0.855500</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.083254</td>
#       <td>0.863667</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.056560</td>
#       <td>0.808566</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.030207</td>
#       <td>0.791279</td>
#       <td>0.733333</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.012573</td>
#       <td>0.767538</td>
#       <td>0.733333</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.996769</td>
#       <td>0.740943</td>
#       <td>0.700000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.982780</td>
#       <td>0.769776</td>
#       <td>0.600000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.969469</td>
#       <td>0.817702</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.960057</td>
#       <td>0.775190</td>
#       <td>0.533333</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.955637</td>
#       <td>0.775190</td>
#       <td>0.533333</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.948675</td>
#       <td>0.775190</td>
#       <td>0.533333</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.943146</td>
#       <td>0.781625</td>
#       <td>0.500000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.940573</td>
#       <td>0.782395</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.dls.bs=len(dls.train_ds)
learn.fit_one_cycle(20, lr_max=1e-3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.849276</td>
#       <td>0.782395</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.859008</td>
#       <td>0.782395</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.849793</td>
#       <td>0.782395</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.835788</td>
#       <td>0.790732</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.839042</td>
#       <td>0.790732</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.839535</td>
#       <td>0.786031</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.839186</td>
#       <td>0.786031</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.835327</td>
#       <td>0.823254</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.834927</td>
#       <td>0.788405</td>
#       <td>0.700000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.838408</td>
#       <td>0.788405</td>
#       <td>0.700000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.838750</td>
#       <td>0.788405</td>
#       <td>0.700000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.840995</td>
#       <td>0.806464</td>
#       <td>0.866667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.840502</td>
#       <td>0.814801</td>
#       <td>0.833333</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.837198</td>
#       <td>0.814802</td>
#       <td>0.833333</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.835407</td>
#       <td>0.814802</td>
#       <td>0.833333</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.834754</td>
#       <td>0.814802</td>
#       <td>0.833333</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.834191</td>
#       <td>0.814802</td>
#       <td>0.833333</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.832064</td>
#       <td>0.783705</td>
#       <td>0.700000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.831366</td>
#       <td>0.820877</td>
#       <td>0.700000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.827585</td>
#       <td>0.820877</td>
#       <td>0.700000</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Results

# %%
learn.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sepal length (cm)</th>
#       <th>sepal width (cm)</th>
#       <th>petal length (cm)</th>
#       <th>petal width (cm)</th>
#       <th>target</th>
#       <th>target_pred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5.5</td>
#       <td>2.4</td>
#       <td>3.7</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5.4</td>
#       <td>3.7</td>
#       <td>1.5</td>
#       <td>0.2</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.8</td>
#       <td>2.7</td>
#       <td>4.1</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.7</td>
#       <td>2.9</td>
#       <td>4.2</td>
#       <td>1.3</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>7.6</td>
#       <td>3.0</td>
#       <td>6.6</td>
#       <td>2.1</td>
#       <td>2.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5.8</td>
#       <td>2.7</td>
#       <td>5.1</td>
#       <td>1.9</td>
#       <td>2.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>4.6</td>
#       <td>3.6</td>
#       <td>1.0</td>
#       <td>0.2</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>5.2</td>
#       <td>4.1</td>
#       <td>1.5</td>
#       <td>0.1</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>5.2</td>
#       <td>3.4</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## wandb ver.

# %%
model = CustomMLP(input_dim, hidden_dim, output_dim)

from fastai.callback.core import Callback
class CustomWandbCallback(WandbCallback):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
    def after_batch(self):
        super().after_batch()
        if self.training:
            self.log_custom_metrics()
    def log_custom_metrics(self):
        self._wandb_step += 1
        custom_metrics = {
            'custom_train_loss': self.learn.loss.item(),
            'custom_lr': self.opt.hypers[-1]['lr'],
            **{f"{name}": wandb.Histogram(param.data.cpu().numpy())
                for name, param in model.named_parameters()},
            **bnn.logger.getLog()
        }
        bnn.logger.clear()
        wandb.log(custom_metrics, step=self._wandb_step)
        
# Learn
wandb.init()  # new Run
learn = Learner(dls, model, loss_func=CrossEntropyLossFlat(), metrics=accuracy,
               cbs=[CustomWandbCallback(), ShowGraphCallback()])
learn.dls.bs=64
learn.fit_one_cycle(500, lr_max=1e-2)
learn.dls.bs=len(dls.train_ds)
learn.fit_one_cycle(100, lr_max=1e-3)
# Out:
# wandb: Currently logged in as: lilacs2039. Use `wandb login --relogin` to force relogin
# wandb version 0.15.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.0
# Run data is saved locally in <code>C:\...\01_expt_flip-backprop\wandb\run-20230508_144348-nt8ecxfs</code>
# Syncing run <strong><a href='https://wandb.ai/lilacs2039/BMALinear-01_expt_flip-backprop/runs/nt8ecxfs' target="_blank">dulcet-pine-1</a></strong> to <a href='https://wandb.ai/lilacs2039/BMALinear-01_expt_flip-backprop' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/lilacs2039/BMALinear-01_expt_flip-backprop' target="_blank">https://wandb.ai/lilacs2039/BMALinear-01_expt_flip-backprop</a>
#  View run at <a href='https://wandb.ai/lilacs2039/BMALinear-01_expt_flip-backprop/runs/nt8ecxfs' target="_blank">https://wandb.ai/lilacs2039/BMALinear-01_expt_flip-backprop/runs/nt8ecxfs</a>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.645215</td>
#       <td>0.931080</td>
#       <td>1.000000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.297665</td>
#       <td>0.931080</td>
#       <td>1.000000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.167041</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.118841</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.089929</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.071184</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.056894</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.046382</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.038930</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.032645</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.027506</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.023226</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.019867</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.016384</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.014054</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.011801</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.010020</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.008342</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.006748</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.005135</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.003765</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.002437</td>
#       <td>1.039408</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.003675</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.002673</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.001753</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.000686</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.999913</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.999197</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.998532</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.997913</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.997463</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.996980</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.997022</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.996517</td>
#       <td>0.969888</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.996396</td>
#       <td>0.982757</td>
#       <td>0.700000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.996050</td>
#       <td>0.989192</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.996184</td>
#       <td>1.014931</td>
#       <td>0.533333</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.996928</td>
#       <td>1.036199</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.998324</td>
#       <td>0.989015</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.997879</td>
#       <td>0.989015</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.997937</td>
#       <td>1.001825</td>
#       <td>0.633333</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.999094</td>
#       <td>1.001825</td>
#       <td>0.633333</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1.000401</td>
#       <td>1.001825</td>
#       <td>0.633333</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1.001440</td>
#       <td>1.001825</td>
#       <td>0.633333</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.002531</td>
#       <td>1.001825</td>
#       <td>0.633333</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.003572</td>
#       <td>1.001825</td>
#       <td>0.633333</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1.003929</td>
#       <td>0.987176</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.001164</td>
#       <td>0.971745</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.996961</td>
#       <td>0.966476</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.993275</td>
#       <td>0.946484</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.990748</td>
#       <td>0.934208</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.988320</td>
#       <td>0.931385</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.985432</td>
#       <td>0.934915</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.983189</td>
#       <td>0.975658</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.982158</td>
#       <td>0.986903</td>
#       <td>0.666667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.981053</td>
#       <td>0.908943</td>
#       <td>0.766667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.978842</td>
#       <td>0.915960</td>
#       <td>0.733333</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.976878</td>
#       <td>0.864425</td>
#       <td>0.733333</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.974348</td>
#       <td>0.864425</td>
#       <td>0.733333</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.972021</td>
#       <td>0.869694</td>
#       <td>0.700000</td>
#       <td>0
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.745774</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.740897</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.728029</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.720379</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.722920</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.724125</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.723394</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.723361</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.725839</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.724535</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.724719</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.723690</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.723644</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.723744</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.721874</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.720643</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.721290</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.720263</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.721052</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.721927</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.722714</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.721374</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.722109</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.722808</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.722846</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.723760</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.723895</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.723614</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.725290</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.725085</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.725013</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.725311</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.726192</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.726229</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.726628</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.726415</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.726307</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.726736</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.726298</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.726309</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.725647</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.725715</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.725675</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.725620</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.725739</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.725401</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.725338</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.725112</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.724364</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.725094</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.725060</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.724391</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.724645</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.724410</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.724862</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.724898</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.724164</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.724565</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.725002</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.725026</td>
#       <td>0.657727</td>
#       <td>0.966667</td>
#       <td>0
